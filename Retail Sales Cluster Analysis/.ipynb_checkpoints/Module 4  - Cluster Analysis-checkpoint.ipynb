# %% [markdown]
# <h1 style="font-size:42px; text-align:center; margin-bottom:30px;"><span style="color:SteelBlue"></span> Cluster Analysis</h1>
# <hr>

# %% [markdown]
# ### Import libraries and load the datasets.

# %%
# NumPy for numerical computing
import numpy as np

# Pandas for DataFrames
import pandas as pd


# Matplotlib for visualization
import matplotlib.pyplot as plt

# display plots in the notebook
# %matplotlib inline

# Seaborn for easier visualization
import seaborn as sns

# Scikit-Learn's make_pipeline function
from sklearn.pipeline import make_pipeline

# Scikit-Learn's StandardScaler
from sklearn.preprocessing import StandardScaler

# Scikit-Learn's KMeans algorithm (added later)
from sklearn.cluster import KMeans

# %%
# Import analytical base table
base_df = pd.read_csv('project_files/analytical-base-table.csv', index_col = 0)

# Import thresholded item features
threshold_item_data = pd.read_csv('project_files/threshold_item_data.csv', index_col = 0)

# Import PCA item features
pca_item_data = pd.read_csv('project_files/pca_item_data.csv', index_col = 0)

# %%
# Print shape of each dataframe
print(base_df.shape)
print(threshold_item_data.shape)
pca_item_data.shape
# Out:
# (414, 8)
# (414, 20)
# (414, 125)

# %% [markdown]
# <span id="k-means"></span>
# # 1. K-Means

# %%
# Join base_df with threshold_item_data
threshold_df = base_df.join(threshold_item_data)

# Display first 5 rows of threshold_df
threshold_df.head()
# Out:
#             total_transactions  total_products  total_unique_products  \
# CustomerID
# 12347                        7             182                    103
# 12348                        4              31                     22
# 12349                        1              73                     73
# 12350                        1              17                     17
# 12352                        8              85                     59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_values  22961  22630  ...   21212  22551  22629  22328  \
# CustomerID                                 ...
# 12347               1294.32      0      0  ...       0      0      0      0
# 12348                892.80      0      0  ...       0      0      0      0
# 12349               1757.55      0      0  ...       0      0      0      0
# 12350                334.40      0      0  ...       0      1      0      0
# 12352                840.30      0      1  ...       0      0      0      0
#
#             21731  22556  22554  22423  22326  POST
# CustomerID
# 12347           5      0      0      4      0     0
# 12348           0      0      0      0      0     4
# 12349           0      1      1      1      1     1
# 12350           0      0      0      0      0     1
# 12352           1      0      0      2      0     5
#
# [5 rows x 28 columns]

# %%
# Join base_df with pca_item_data
pca_df = base_df.join(pca_item_data)

# Display first 5 rows of pca_df
pca_df.head()
# Out:
#             total_transactions  total_products  total_unique_products  \
# CustomerID
# 12347                        7             182                    103
# 12348                        4              31                     22
# 12349                        1              73                     73
# 12350                        1              17                     17
# 12352                        8              85                     59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_values       PC1       PC2    ...        PC116     PC117  \
# CustomerID                                         ...
# 12347               1294.32  5.876141  4.828892    ...    -0.007766 -0.779199
# 12348                892.80 -4.219839  1.226195    ...    -1.904435  0.075644
# 12349               1757.55 -1.260838  2.387828    ...     4.595645 -4.527504
# 12350                334.40 -4.929319 -0.714874    ...    -1.869817 -0.460085
# 12352                840.30 -2.053129  2.110788    ...     1.695937  8.096258
#
#                 PC118     PC119     PC120     PC121     PC122     PC123  \
# CustomerID
# 12347        0.613359 -0.330509 -0.004962 -0.045697  0.148163 -0.061750
# 12348       -0.955823  1.409611  0.724342  0.464916  1.907702 -1.416770
# 12349       -2.370799 -3.396166 -3.419379 -1.304617  3.845541  0.807568
# 12350       -1.192275 -0.596812 -0.808693  0.373854 -0.282510 -0.819361
# 12352       10.325739 -8.947321 -3.582689 -2.078227  3.346192  5.183793
#
#                PC124     PC125
# CustomerID
# 12347      -0.198612 -0.269058
# 12348       1.121250 -2.946993
# 12349      -4.652684  2.594639
# 12350      -1.010051  0.363232
# 12352       0.928319 -1.933235
#
# [5 rows x 133 columns]

# %% [markdown]
# <span id="base"></span>
# # 2. Base DF
#
# The first set of features we'll consider is **"Base DF"** which only includes the purchase pattern features from our analytical base table.

# %%
# First 5 observations of base_df
base_df.head()
# Out:
#             total_transactions  total_products  total_unique_products  \
# CustomerID
# 12347                        7             182                    103
# 12348                        4              31                     22
# 12349                        1              73                     73
# 12350                        1              17                     17
# 12352                        8              85                     59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_values
# CustomerID
# 12347               1294.32
# 12348                892.80
# 12349               1757.55
# 12350                334.40
# 12352                840.30

# %%
# K-Means model pipeline
k_means_base_df = make_pipeline(StandardScaler(), KMeans(random_state = 123, n_clusters = 3))

# %%
# Fit K-Means pipeline
k_means_base_df.fit(base_df)
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('kmeans', KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=123, tol=0.0001, verbose=0))])

# %%
# Save clusters to base_df
base_df['cluster'] = k_means_base_df.predict(base_df)

# Display first 5 rows of base_df
base_df.head()
# Out:
#             total_transactions  total_products  total_unique_products  \
# CustomerID
# 12347                        7             182                    103
# 12348                        4              31                     22
# 12349                        1              73                     73
# 12350                        1              17                     17
# 12352                        8              85                     59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_values  cluster
# CustomerID
# 12347               1294.32        1
# 12348                892.80        0
# 12349               1757.55        0
# 12350                334.40        0
# 12352                840.30        0

# %%
# Scatterplot, colored by cluster
sns.set_style("darkgrid")
sns.lmplot(x='total_sales', y='avg_cart_value', hue = 'cluster', data = base_df, fit_reg = False)
plt.show()

# %% [markdown]
# <span id="threshold"></span>
# # Threshold DF
#
# The second set of features we'll consider is **"Threshold DF"**.
# * This includes the purchase pattern features from our analytical base table.
# * This also includes the purchase counts for the 20 most popular items.

# %%
# K-Means model pipeline
k_means_threshold_df = make_pipeline(StandardScaler(), KMeans(random_state = 123, n_clusters = 3))

# %%
# Fit K-Means pipeline
k_means_threshold_df.fit(threshold_df)
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('kmeans', KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=123, tol=0.0001, verbose=0))])

# %%
# Save clusters to threshold_df
threshold_df['cluster'] = k_means_threshold_df.predict(threshold_df)
# Display first 5 rows of threshold_df
threshold_df.head()
# Out:
#             total_transactions  total_products  total_unique_products  \
# CustomerID
# 12347                        7             182                    103
# 12348                        4              31                     22
# 12349                        1              73                     73
# 12350                        1              17                     17
# 12352                        8              85                     59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_values  22961  22630   ...     22551  22629  22328  \
# CustomerID                                  ...
# 12347               1294.32      0      0   ...         0      0      0
# 12348                892.80      0      0   ...         0      0      0
# 12349               1757.55      0      0   ...         0      0      0
# 12350                334.40      0      0   ...         1      0      0
# 12352                840.30      0      1   ...         0      0      0
#
#             21731  22556  22554  22423  22326  POST  cluster
# CustomerID
# 12347           5      0      0      4      0     0        0
# 12348           0      0      0      0      0     4        2
# 12349           0      1      1      1      1     1        2
# 12350           0      0      0      0      0     1        2
# 12352           1      0      0      2      0     5        2
#
# [5 rows x 29 columns]

# %%
# Scatterplot, colored by cluster
sns.lmplot(x = 'total_sales', y = 'avg_cart_value', data = threshold_df, fit_reg = False, hue = "cluster")
plt.show()

# %% [markdown]
# <span id="pca"></span>
# # PCA DF
#
# The last set of features we'll consider is **"PCA DF"**.
# * This includes the purchase pattern features from our analytical base table.
# * This also includes the first 125 principal component features from the item data.
#
#
# <br>

# %%
# K-Means model pipeline
k_means_pca_df = make_pipeline(StandardScaler(), KMeans(random_state = 123, n_clusters = 3))

# %%
# Fit K-Means pipeline
k_means_pca_df.fit(pca_df)
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('kmeans', KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=123, tol=0.0001, verbose=0))])

# %%
# Save clusters to pca_df
pca_df['cluster'] = k_means_pca_df.predict(pca_df)

# Display first 5 rows of pca_df
pca_df.head()
# Out:
#             total_transactions  total_products  total_unique_products  \
# CustomerID
# 12347                        7             182                    103
# 12348                        4              31                     22
# 12349                        1              73                     73
# 12350                        1              17                     17
# 12352                        8              85                     59
#
#             total_sales  avg_product_value  avg_cart_value  min_cart_value  \
# CustomerID
# 12347           4310.00          23.681319      615.714286          224.82
# 12348           1797.24          57.975484      449.310000          227.44
# 12349           1757.55          24.076027     1757.550000         1757.55
# 12350            334.40          19.670588      334.400000          334.40
# 12352           2506.04          29.482824      313.255000          120.33
#
#             max_cart_values       PC1       PC2   ...        PC117      PC118  \
# CustomerID                                        ...
# 12347               1294.32  5.876141  4.828892   ...    -0.779199   0.613359
# 12348                892.80 -4.219839  1.226195   ...     0.075644  -0.955823
# 12349               1757.55 -1.260838  2.387828   ...    -4.527504  -2.370799
# 12350                334.40 -4.929319 -0.714874   ...    -0.460085  -1.192275
# 12352                840.30 -2.053129  2.110788   ...     8.096258  10.325739
#
#                PC119     PC120     PC121     PC122     PC123     PC124  \
# CustomerID
# 12347      -0.330509 -0.004962 -0.045697  0.148163 -0.061750 -0.198612
# 12348       1.409611  0.724342  0.464916  1.907702 -1.416770  1.121250
# 12349      -3.396166 -3.419379 -1.304617  3.845541  0.807568 -4.652684
# 12350      -0.596812 -0.808693  0.373854 -0.282510 -0.819361 -1.010051
# 12352      -8.947321 -3.582689 -2.078227  3.346192  5.183793  0.928319
#
#                PC125  cluster
# CustomerID
# 12347      -0.269058        0
# 12348      -2.946993        0
# 12349       2.594639        0
# 12350       0.363232        0
# 12352      -1.933235        0
#
# [5 rows x 134 columns]

# %%
# Scatterplot, colored by cluster
sns.lmplot(x = 'total_sales', y = 'avg_cart_value',
           data = pca_df, fit_reg = False, hue = 'cluster')
plt.show()

# %% [markdown]
# <span id="comparison"></span>
# # Model comparison
#
# Each of those 3 dataframes have the same indices:

# %%
# Check all indices are identical
print( all( base_df.index == threshold_df.index ) )
print( all( base_df.index == pca_df.index) )
# Out:
# True
# True

# %%
# Adjusted Rand index
from sklearn.metrics import adjusted_rand_score

# %%
# Similary between base_df.cluster and threshold_df.cluster

print(adjusted_rand_score(base_df.cluster, threshold_df.cluster))
# Out:
# 0.6021354951782343

# %%
# Similary between threshold_df.cluster and pca_df.cluster
adjusted_rand_score(threshold_df.cluster, pca_df.cluster)
# Out:
# 0.033220422032313936

# %%
# Similary between base_df.cluster and pca_df.cluster
adjusted_rand_score(base_df.cluster, pca_df.cluster)
# Out:
# 0.042311307744307906

# %% [markdown]
# **We notice that compared to pca_df.cluster, threshold_df.cluster is more like the one created from the base_df.**
