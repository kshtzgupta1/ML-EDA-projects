# %% [markdown]
# <h1 style="font-size:42px; text-align:center; margin-bottom:30px;"><span style="color:SteelBlue"></span> Exploratory Analysis</h1>
# <hr>

# %% [markdown]
# **In this dataset we are trying to predict employee retention in a company. Our target variable is <span style="color:royalblue">status</span> which takes two values <span style="color:red">Employed</span>  or <span style="color:red">Left</span> and we have to predict this status. **

# %% [markdown]
# ### First, let's import libraries and load the dataset.

# %%
# NumPy for numerical computing
import numpy as np
# Pandas for DataFrames
import pandas as pd

# Matplotlib for visualization
from matplotlib import pyplot as plt
# display plots in the notebook
# %matplotlib inline
# Seaborn for easier visualization
import seaborn as sns

# %% [markdown]
# Next, let's import the dataset.
# * The file path is <code style="color:crimson">'project_files/employee_data.csv'</code>

# %%
# Load employee data from CSV
df = pd.read_csv('project_files/employee_data.csv')

# %% [markdown]
# Now we're ready to jump into exploring the data!

# %% [markdown]
# <span id="basic"></span>
# # 1. Basic information
#
# Let's begin by displaying the dataset's basic information.
#
# <br>

# %%
# Dataframe dimensions
df.shape
# Out:
# (14249, 10)

# %% [markdown]
# **We have 14,249 observations and 10 features (inlcuding the target feature).**
# <br>
#
# </br>

# %% [markdown]
# **Next, let's display the <span style="color:royalblue">datatypes</span> of the features.**

# %%
# Column datatypes
df.dtypes
# Out:
# avg_monthly_hrs        int64
# department            object
# filed_complaint      float64
# last_evaluation      float64
# n_projects             int64
# recently_promoted    float64
# salary                object
# satisfaction         float64
# status                object
# tenure               float64
# dtype: object

# %% [markdown]
# **Next, display the first 10 <span style="color:royalblue">example observations</span> from the dataset.**

# %%
# First 10 rows of data
df.head()
# Out:
#    avg_monthly_hrs   department  filed_complaint  last_evaluation  n_projects  \
# 0              221  engineering              NaN         0.932868           4
# 1              232      support              NaN              NaN           3
# 2              184        sales              NaN         0.788830           3
# 3              206        sales              NaN         0.575688           4
# 4              249        sales              NaN         0.845217           3
#
#    recently_promoted  salary  satisfaction    status  tenure
# 0                NaN     low      0.829896      Left     5.0
# 1                NaN     low      0.834544  Employed     2.0
# 2                NaN  medium      0.834988  Employed     3.0
# 3                NaN     low      0.424764  Employed     2.0
# 4                NaN     low      0.779043  Employed     3.0

# %% [markdown]
# **Finally, display the last 10 rows of data to check for any signs of <span style="color:royalblue">corrupted data</span>.**

# %%
# Last 10 rows of data
df.tail()
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 14244              178         IT              NaN         0.735865
# 14245              257      sales              NaN         0.638604
# 14246              232    finance              1.0         0.847623
# 14247              130         IT              NaN         0.757184
# 14248              159        NaN              NaN         0.578742
#
#        n_projects  recently_promoted  salary  satisfaction    status  tenure
# 14244           5                NaN     low      0.263282  Employed     5.0
# 14245           3                NaN     low      0.868209  Employed     2.0
# 14246           5                NaN  medium      0.898917      Left     5.0
# 14247           4                NaN  medium      0.641304  Employed     3.0
# 14248           3                NaN  medium      0.808850  Employed     3.0

# %% [markdown]
# **In this case it doesn't seem like we have any corrupted data.**

# %% [markdown]
# <span id="numeric"></span>
# # 2. Distributions of numeric features

# %%
# Plot histogram grid
sns.set(style = 'darkgrid')
df.hist(xrot = -45, figsize = (12,12))
# Clear the text "residue"
plt.show()

# %%
# View histograms by employed/left
df.groupby('status').hist(xrot = -45, figsize = (10,10))
plt.show()

# Attribute Histogram Matrix for Class 'Employed' followed by
# Attribute Histogram Matrix for Class 'Left'

# %%
# Summarize numerical features
df.describe()
# Out:
#        avg_monthly_hrs  filed_complaint  last_evaluation    n_projects  \
# count     14249.000000           2058.0     12717.000000  14249.000000
# mean        199.795775              1.0         0.718477      3.773809
# std          50.998714              0.0         0.173062      1.253126
# min          49.000000              1.0         0.316175      1.000000
# 25%         155.000000              1.0         0.563866      3.000000
# 50%         199.000000              1.0         0.724939      4.000000
# 75%         245.000000              1.0         0.871358      5.000000
# max         310.000000              1.0         1.000000      7.000000
#
#        recently_promoted  satisfaction        tenure
# count              300.0  14068.000000  14068.000000
# mean                 1.0      0.621295      3.497228
# std                  0.0      0.250469      1.460917
# min                  1.0      0.040058      2.000000
# 25%                  1.0      0.450390      3.000000
# ...

# %% [markdown]
# #### Correlation Heatmap
# Let's plot a correlation heatmap to further investigate the relationship between the numerical features.

# %%
# Calculate correlations between numeric features
df.corr()

# %%
# Plot correlation heatmap

# Make the figsize 9 x 8
plt.figure(figsize = (9,8))
correlations = df.corr()
sns.set(style = "white")
mask = np.zeros_like(correlations, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True
# Plot heatmap of correlations
sns.heatmap(correlations*100, mask = mask, fmt = ".0f", cbar = False, annot = True, color = "green")
plt.show()

# %% [markdown]
# There seems to be a weak positive correlation between number of projects and avg_monthly_hours

# %% [markdown]
# <span id="categorical"></span>
# # 3. Distributions of categorical features
#
# Next, let's take a look at the distributions of our categorical features.

# %%
# Summarize categorical features
df.describe(include = "object")
# Out:
#        department salary    status
# count       13540  14249     14249
# unique         12      3         2
# top         sales    low  Employed
# freq         3923   6952     10857

# %%
# Plot bar plot for each categorical feature
categorical_features = df.select_dtypes(include = 'object').columns.values
plt.figure(figsize = (10, 10))
for feature in categorical_features:
    sns.countplot(y = feature, data = df)
    plt.show()

# %% [markdown]
# In the countplot for department we notice a class, 'temp' which is irrelevant to our analysis. In addition to sparse classes, there seem to be duplicate classes like 'IT' & 'information management'. We will handle these in data cleaning.

# %% [markdown]
# <span id="segmentations"></span>
# # 4. Segmentations

# %%
# Segment satisfaction by status and plot distributions
plt.figure(figsize = (8,8))
sns.violinplot(y = 'status', x ='satisfaction', data = df)
plt.show()

# %% [markdown]
# This chart compares of the distributions of satisfaction between employees who've left and those that are still employed.
# Those still employed tend to more satisfied, which makes intuitive sense.

# %%
# Segment last_evaluation by status and plot distributions
plt.figure(figsize = (8,8))
sns.violinplot(y = 'status', x ='last_evaluation', data = df)
plt.show()

# %% [markdown]
# This chart compares of the distributions of last_evaluations between employees who've left and those that are still employed. Tthe distribution for those who've left seem a bit peculiar. We will investigate this further later.

# %%
# Segment by status and display the means within each class

df.groupby('status').mean()
# Out:
#           avg_monthly_hrs  filed_complaint  last_evaluation  n_projects  \
# status
# Employed       197.700286              1.0         0.714479    3.755273
# Left           206.502948              1.0         0.730706    3.833137
#
#           recently_promoted  satisfaction    tenure
# status
# Employed                1.0      0.675979  3.380245
# Left                    1.0      0.447500  3.869023

# %% [markdown]
# <span id="advanced-segmentations"></span>
# # 5. Advanced segmentations
#
# Because our target variable 'status' is categorical, it can often be helpful to conduct segmentation analysis.

# %%
# Scatterplot of satisfaction vs. last_evaluation

plt.figure(figsize = (8,8))
sns.lmplot(x = 'satisfaction',
           y ='last_evaluation', data = df, scatter_kws= {'alpha': 0.2}, hue = 'status', fit_reg = False)

plt.show()

# %% [markdown]
# This chart is too cluttered.
# Instead, it might be more helpful to plot a separate scatterplot just for those who've 'Left'

# %%
# Scatterplot of satisfaction vs. last_evaluation, only those who have left
sns.lmplot(x = 'satisfaction',
           y ='last_evaluation', data = df[df.status == 'Left'], fit_reg = False)
plt.show()

# %% [markdown]
# It looks like there are three clusters of people who've left. Maybe we can explicitly highlight these clusters by creating 3 indicator features during feature engineering:
#
# "Underperformers: for last_evaluation < 0.6
#
# "Unhappy" for satisfaction_level < 0.2... maybe they are overqualified?
#
# "Overachievers" last_evaluation > 0.8 and satisfaction > 0.7

# %% [markdown]
# <br>
# ## Next Steps
#
# Moving on we will work on the ABT Construction by data cleaning and engineering new features.
